# %%
import skimage.transform as skt
import os
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import numpy as np
from skimage.io import imread

# %%
path_to_data="F:\Libraries\Documents\ALL\School\GrDip\comp6721_applied_artificial_intelligence\project\FaceMaskCNN\data\masktype\Dataset"

# %%
path_dict = {}
for c in os.listdir(path_to_data):
    path_dict[c] = os.path.join(path_to_data, c)

# %%
os.listdir(path_dict["cloth_mask"])[0]
# Out:
# '0018.jpg'

# %%
def get_image(c, imname):
    img = imread(os.path.join(path_dict[c], imname))
    return img

# %%
img = get_image("cloth_mask_TF", "showcase.jpg")
imshow(img)

# %%
resized = skt.resize(img, (64, 64), anti_aliasing=False)

# %%
imshow(resized)
